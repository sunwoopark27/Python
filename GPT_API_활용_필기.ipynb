# %% [markdown]
# https://platform.openai.com/api-keys

# %%
API = "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"

# %%
# 멋사것으로 돌릴 떄마다 돈나감

# %%
# !pip install --upgrade openapi --quiet

# %%
import json
from openai import OpenAI
import os
from google.colab import userdata

# %%
# 위사이트 우측 상단에 docs 누르면 어떤 모델을 사용할 수 있는지 볼 수 있음

# %%
MODEL = 'gpt-4o'

# %%
client = OpenAI(api_key=API)

# %%
completion = client.chat.completions.create(
    model=MODEL,
    messages=[
        {
            "role": "system",
            "content": "넌 약사입니다"
        },
        {
            "role": "user",
            "content": "배가 찌르듯이 아픕니다!"
        }
    ]
)

# %%
print("Assistant: " + completion.choices[0].message.content)
# Out:
# Assistant: 배가 찌르듯이 아프다면 즉시 병원이나 응급실을 방문하여 정확한 진단을 받는 것이 중요합니다. 복통은 여러 가지 원인에 의해 발생할 수 있으며, 특히 갑작스럽고 심한 통증은 신속한 의료적 평가가 필요할 수 있습니다. 가능한 원인으로는 맹장염, 췌장염, 신장결석, 장폐색 등이 있을 수 있습니다. 정확한 진단을 위해 의료 전문가의 평가를 받는 것이 가장 안전합니다.

# %%
import json

# %%
completion = client.chat.completions.create(
    model=MODEL,
    response_format = {"type" : "json_object"},
    messages=[
        {
            "role": "system",
            "content": "JSON 형태로 대답해줘"
        },
        {
            "role": "user",
            "content": "일주일 운동루틴을 작성해주세요"
        }
    ]
)

# %%
print(completion.choices[0].message.content)
# Out:
# {
#     "월요일": {
#         "운동": "상체 운동",
#         "루틴": [
#             "벤치프레스 - 4세트 x 8-12회",
#             "덤벨 숄더 프레스 - 3세트 x 10-15회",
#             "풀업 - 3세트 x 최대한 반복",
#             "덤벨 로우 - 3세트 x 8-12회",
#             "트라이셉스 익스텐션 - 3세트 x 10-15회"
#         ]
#     },
#     "화요일": {
#         "운동": "하체 운동",
#         "루틴": [
#             "스쿼트 - 4세트 x 8-12회",
#             "레그 프레스 - 3세트 x 10-15회",
#             "루마니안 데드리프트 - 3세트 x 8-12회",
#             "레그 컬 - 3세트 x 10-15회",
#             "카프 레이즈 - 3세트 x 10-15회"
#         ]
#     },
#     "수요일": {
#         "운동": "유산소 및 코어 운동",
#         "루틴": [
#             "조깅 또는 고정자전거 - 20-30분",
#             "플랭크 - 3세트 x 30-60초",
#             "러시안 트위스트 - 3세트 x 20회",
#             "바이시클 크런치 - 3세트 x 15-20회"
#         ]
#     },
#     "목요일": {
#         "운동": "상체 운동",
#         "루틴": [
#             "인클라인 벤치프레스 - 4세트 x 8-12회",
#             "랫 풀다운 - 3세트 x 10-15회",
#             "어놀드 프레스 - 3세트 x 10-15회",
#             "바벨 컬 - 3세트 x 10-15회",
# ...

# %%
json.loads(completion.choices[0].message.content)
# Out:
# {'월요일': {'운동': '상체 운동',
#   '루틴': ['벤치프레스 - 4세트 x 8-12회',
#    '덤벨 숄더 프레스 - 3세트 x 10-15회',
#    '풀업 - 3세트 x 최대한 반복',
#    '덤벨 로우 - 3세트 x 8-12회',
#    '트라이셉스 익스텐션 - 3세트 x 10-15회']},
#  '화요일': {'운동': '하체 운동',
#   '루틴': ['스쿼트 - 4세트 x 8-12회',
#    '레그 프레스 - 3세트 x 10-15회',
#    '루마니안 데드리프트 - 3세트 x 8-12회',
#    '레그 컬 - 3세트 x 10-15회',
#    '카프 레이즈 - 3세트 x 10-15회']},
#  '수요일': {'운동': '유산소 및 코어 운동',
#   '루틴': ['조깅 또는 고정자전거 - 20-30분',
#    '플랭크 - 3세트 x 30-60초',
#    '러시안 트위스트 - 3세트 x 20회',
#    '바이시클 크런치 - 3세트 x 15-20회']},
#  '목요일': {'운동': '상체 운동',
#   '루틴': ['인클라인 벤치프레스 - 4세트 x 8-12회',
#    '랫 풀다운 - 3세트 x 10-15회',
#    '어놀드 프레스 - 3세트 x 10-15회',
#    '바벨 컬 - 3세트 x 10-15회',
#    '페이스 풀 - 3세트 x 12-15회']},
#  '금요일': {'운동': '하체 및 힙 운동',
#   '루틴': ['데드리프트 - 4세트 x 8-12회',
#    '런지 - 3세트 x 10-15회 각 다리',
#    '힙 쓰러스트 - 3세트 x 10-15회',
#    '레그 익스텐션 - 3세트 x 10-15회']},
#  '토요일': {'운동': '휴식 또는 가벼운 활동',
#   '루틴': ['요가 또는 스트레칭 클래스', '또는 가벼운 하이킹', '또는 수영']},
# ...

# %%
from IPython.display import Image,display
import base64

# %%
IMG_PATH = '/content/unnamed.jpg'

# %%
def encode_image(img_path):
    with open(img_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

# %%
base64_image = encode_image(IMG_PATH)

# %%
display(Image(IMG_PATH))

# %%
completion = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "너는 이미지를 설명해주는 역할이야"},
        {"role": "user", "content": [
            {"type": "text", "text": "어떤 이미지가 들어있니?"},
            {"type": "image_url", "image_url": {"url": f"data:image/png;base64,{base64_image}"}}
        ]}
    ],
    temperature=0.0,
)

# %%
print(completion.choices[0].message.content)
# Out:
# 이미지에는 작은 줄무늬 고양이가 한쪽 앞발을 들어 올리고 있는 모습이 담겨 있습니다. 고양이는 귀엽고 호기심 많은 표정을 짓고 있으며, 흰색 배경 위에 서 있습니다.

# %%
# 이미지 인식하게 하고, 카메라 중점과 움직일 수 있는 모터 연결
# action -> chatgpt가 action 명령

# %% [markdown]
# -----
# # url 이미지 읽기

# %%
response = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "너는 이미지를 설명해주는 역할이야"},
        {"role": "user", "content": [
            {"type": "text", "text": "이미지가 어떤걸 묘사하고 있니?"},
            {"type": "image_url", "image_url": {"url": "https://www.fitpetmall.com/wp-content/uploads/2023/10/image-14.png"}}
        ]}
    ],
    temperature=0.0,
)

print(response.choices[0].message.content)
# Out:
# 이미지에는 작은 흰색 강아지가 나무 데크 위에 앉아 있는 모습이 묘사되어 있습니다. 강아지 옆에는 노란 꽃들이 피어 있는 초록색 풀밭이 보입니다. 강아지는 혀를 내밀고 있어 매우 행복해 보입니다.
