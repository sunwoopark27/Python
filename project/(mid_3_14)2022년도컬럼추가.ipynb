# %%
import pandas as pd
df_2023 = pd.read_csv('/content/WHR2023.csv')

# %%
df_2023.head()
# Out:
#   Country name  Ladder score  Standard error of ladder score  upperwhisker  \
# 0      Finland         7.804                           0.036         7.875
# 1      Denmark         7.586                           0.041         7.667
# 2      Iceland         7.530                           0.049         7.625
# 3       Israel         7.473                           0.032         7.535
# 4  Netherlands         7.403                           0.029         7.460
#
#    lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.733                 10.792           0.969
# 1         7.506                 10.962           0.954
# 2         7.434                 10.896           0.983
# 3         7.411                 10.639           0.943
# 4         7.346                 10.942           0.930
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                   71.150                         0.961      -0.019
# ...

# %%
one.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900826
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
a = pd.read_excel('/content/WHR20_DataForFigure2.1.xls')
a.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900826
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
b= pd.read_csv('/content/WHR_2020.csv')
b.head()
# Out:
#        country          region  happiness_score  gdp_per_capita  \
# 0      Finland  Western Europe           7.8087        1.285190
# 1      Denmark  Western Europe           7.6456        1.326949
# 2  Switzerland  Western Europe           7.5599        1.390774
# 3      Iceland  Western Europe           7.5045        1.326502
# 4       Norway  Western Europe           7.4880        1.424207
#
#    social_support  healthy_life_expectancy  freedom_to_make_life_choices  \
# 0        1.499526                 0.961271                      0.662317
# 1        1.503449                 0.979333                      0.665040
# 2        1.472403                 1.040533                      0.628954
# 3        1.547567                 1.000843                      0.661981
# 4        1.495173                 1.008072                      0.670201
#
#    generosity  perceptions_of_corruption
# 0    0.159670                   0.477857
# 1    0.242793                   0.495260
# ...

# %%
# 숫자형 열만 선택
numeric_columns = b.select_dtypes(include=['float64', 'int64']).columns

# 숫자형 열들 간의 상관계수 계산
correlation_matrix = b[numeric_columns].corr()

# %%
correlation_matrix
# Out:
#                               happiness_score  gdp_per_capita  social_support  \
# happiness_score                      1.000000        0.775374        0.765001
# gdp_per_capita                       0.775374        1.000000        0.781814
# social_support                       0.765001        0.781814        1.000000
# healthy_life_expectancy              0.770316        0.848469        0.742744
# freedom_to_make_life_choices         0.590597        0.419019        0.478863
# generosity                           0.069043       -0.118399       -0.056780
# perceptions_of_corruption            0.418305        0.334729        0.210530
#
#                               healthy_life_expectancy  \
# happiness_score                              0.770316
# gdp_per_capita                               0.848469
# social_support                               0.742744
# healthy_life_expectancy                      1.000000
# freedom_to_make_life_choices                 0.448846
# ...

# %%
a.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900826
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
# 'country'별로 그룹화하여 상관계수 계산
country_corr = b.groupby('country')[numeric_columns].corr()
country_corr['happiness_score']
# Out:
# country
# Afghanistan  happiness_score                NaN
#              gdp_per_capita                 NaN
#              social_support                 NaN
#              healthy_life_expectancy        NaN
#              freedom_to_make_life_choices   NaN
#                                              ..
# Zimbabwe     social_support                 NaN
#              healthy_life_expectancy        NaN
#              freedom_to_make_life_choices   NaN
#              generosity                     NaN
#              perceptions_of_corruption      NaN
# Name: happiness_score, Length: 1071, dtype: float64

# %%
# 숫자형 열만 선택
numeric_columns = b.select_dtypes(include=['float64', 'int64']).columns

# 전체 데이터에 대해 상관계수 계산
correlation_matrix = b[numeric_columns].corr()

# 'happiness_score'와 다른 변수들 간의 상관계수 추출
correlation_matrix['happiness_score']
# Out:
# happiness_score                 1.000000
# gdp_per_capita                  0.775374
# social_support                  0.765001
# healthy_life_expectancy         0.770316
# freedom_to_make_life_choices    0.590597
# generosity                      0.069043
# perceptions_of_corruption       0.418305
# Name: happiness_score, dtype: float64

# %%
b.head()
# Out:
#        country          region  happiness_score  gdp_per_capita  \
# 0      Finland  Western Europe           7.8087        1.285190
# 1      Denmark  Western Europe           7.6456        1.326949
# 2  Switzerland  Western Europe           7.5599        1.390774
# 3      Iceland  Western Europe           7.5045        1.326502
# 4       Norway  Western Europe           7.4880        1.424207
#
#    social_support  healthy_life_expectancy  freedom_to_make_life_choices  \
# 0        1.499526                 0.961271                      0.662317
# 1        1.503449                 0.979333                      0.665040
# 2        1.472403                 1.040533                      0.628954
# 3        1.547567                 1.000843                      0.661981
# 4        1.495173                 1.008072                      0.670201
#
#    generosity  perceptions_of_corruption
# 0    0.159670                   0.477857
# 1    0.242793                   0.495260
# ...

# %%
# 결과적으로 년도별 비교를 위해 9개의 컬럼만 비교하기로 하였다.

# %%
import pandas as pd
df_2022 = pd.read_csv('/content/WHR_2022.csv')
df_2022.head()
# Out:
#        country          region  happiness_score  gdp_per_capita  \
# 0      Finland  Western Europe            7.821           1.892
# 1      Denmark  Western Europe            7.636           1.953
# 2      Iceland  Western Europe            7.557           1.936
# 3  Switzerland  Western Europe            7.512           2.026
# 4  Netherlands  Western Europe            7.415           1.945
#
#    social_support  healthy_life_expectancy  freedom_to_make_life_choices  \
# 0           1.258                    0.775                         0.736
# 1           1.243                    0.777                         0.719
# 2           1.320                    0.803                         0.718
# 3           1.226                    0.822                         0.677
# 4           1.206                    0.787                         0.651
#
#    generosity  perceptions_of_corruption
# 0       0.109                      0.534
# 1       0.188                      0.532
# ...

# %%
# 'year' 컬럼 추가하고 값 모든 값 2022로 설정
df_2022['year'] = 2022

# %%
# 결과 확인
df_2022.head()  # 데이터 일부 출력
# Out:
#        country          region  happiness_score  gdp_per_capita  \
# 0      Finland  Western Europe            7.821           1.892
# 1      Denmark  Western Europe            7.636           1.953
# 2      Iceland  Western Europe            7.557           1.936
# 3  Switzerland  Western Europe            7.512           2.026
# 4  Netherlands  Western Europe            7.415           1.945
#
#    social_support  healthy_life_expectancy  freedom_to_make_life_choices  \
# 0           1.258                    0.775                         0.736
# 1           1.243                    0.777                         0.719
# 2           1.320                    0.803                         0.718
# 3           1.226                    0.822                         0.677
# 4           1.206                    0.787                         0.651
#
#    generosity  perceptions_of_corruption  year
# 0       0.109                      0.534  2022
# ...

# %%
df_2022.to_csv('/content/WHR_2022_year.csv', index=False)
